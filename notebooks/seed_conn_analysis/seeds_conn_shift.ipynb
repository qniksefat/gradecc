# %% [markdown]
# regions

# %%
from gradecc.compute.measures import get_measures
from gradecc.plot import plot_cortex
from gradecc.stats import rm_anova

df = get_measures()
df_stats = rm_anova(df)
df_stats_ecc = df_stats[df_stats.measure == 'eccentricity']

plot_cortex(df_stats_ecc, 'F', 'pvalue_corrected',
           color_range=(1, 10), layout='grid')
# Out:
# Reading data from /Users/qasem/Dropbox/JasonANDQasem_SHARED/codes/gradients-rl-task/data/measures.csv

# %%
sig_regions = df_stats_ecc[df_stats_ecc.fdr_significant == True].region.tolist()
sig_regions
# Out:
# ['7Networks_LH_Cont_Cing_8',
#  '7Networks_LH_Default_PFC_19',
#  '7Networks_LH_Default_PFC_23',
#  '7Networks_LH_Default_PFC_27',
#  '7Networks_LH_Default_PFC_30',
#  '7Networks_LH_Default_PFC_46',
#  '7Networks_LH_Default_PFC_8',
#  '7Networks_LH_Default_Temp_13',
#  '7Networks_LH_Default_Temp_17',
#  '7Networks_LH_Default_Temp_18',
#  '7Networks_LH_Default_Temp_19',
#  '7Networks_LH_Default_Temp_21',
#  '7Networks_LH_Default_Temp_3',
#  '7Networks_LH_Default_pCunPCC_1',
#  '7Networks_LH_Default_pCunPCC_10',
#  '7Networks_LH_Default_pCunPCC_12',
#  '7Networks_LH_Default_pCunPCC_2',
#  '7Networks_LH_Default_pCunPCC_3',
#  '7Networks_LH_Default_pCunPCC_4',
#  '7Networks_LH_Default_pCunPCC_5',
#  '7Networks_LH_Default_pCunPCC_7',
#  '7Networks_LH_DorsAttn_FEF_5',
#  '7Networks_LH_DorsAttn_FEF_6',
#  '7Networks_LH_Limbic_OFC_4',
#  '7Networks_LH_Limbic_OFC_9',
#  '7Networks_LH_Limbic_TempPole_10',
#  '7Networks_LH_SalVentAttn_Med_13',
#  '7Networks_LH_SalVentAttn_Med_16',
#  '7Networks_LH_Vis_34',
#  '7Networks_LH_Vis_5',
#  '7Networks_RH_Cont_PFCl_28',
#  '7Networks_RH_Cont_PFCl_34',
#  '7Networks_RH_Cont_pCun_2',
#  '7Networks_RH_Default_PFCdPFCm_1',
#  '7Networks_RH_Default_PFCdPFCm_13',
#  '7Networks_RH_Default_PFCdPFCm_8',
#  '7Networks_RH_Default_Par_14',
#  '7Networks_RH_Default_Temp_1',
#  '7Networks_RH_Default_Temp_16',
#  '7Networks_RH_Default_Temp_3',
#  '7Networks_RH_Default_pCunPCC_15',
#  '7Networks_RH_Default_pCunPCC_2',
#  '7Networks_RH_Default_pCunPCC_3',
#  '7Networks_RH_Default_pCunPCC_4',
#  '7Networks_RH_Default_pCunPCC_6',
#  '7Networks_RH_Default_pCunPCC_7',
#  '7Networks_RH_Default_pCunPCC_9',
#  '7Networks_RH_DorsAttn_Post_40',
#  '7Networks_RH_DorsAttn_Post_46',
#  '7Networks_RH_Limbic_OFC_10',
#  '7Networks_RH_Limbic_OFC_9',
#  '7Networks_RH_SalVentAttn_FrOperIns_14',
#  '7Networks_RH_SomMot_76',
#  '7Networks_RH_Vis_31',
#  '7Networks_RH_Vis_52',
#  '7Networks_RH_Vis_74',
#  '7Networks_RH_Vis_77']

# %% [markdown]
# plot

# %%
import operator

rois = [1, 4, 7, 15, 17, 20, 27, 30, 45]
rois = operator.itemgetter(*rois)(sig_regions)
rois
# Out:
# ('7Networks_LH_Default_PFC_19',
#  '7Networks_LH_Default_PFC_30',
#  '7Networks_LH_Default_Temp_13',
#  '7Networks_LH_Default_pCunPCC_12',
#  '7Networks_LH_Default_pCunPCC_3',
#  '7Networks_LH_Default_pCunPCC_7',
#  '7Networks_LH_SalVentAttn_Med_16',
#  '7Networks_RH_Cont_PFCl_28',
#  '7Networks_RH_Default_pCunPCC_7')

# %%
from gradecc.plot.utils import spot_region
from gradecc.plot import plot_cortex

for sample_region in rois:
    plot_cortex(spot_region(sample_region), layout='grid',
           text=sample_region[10:], as_outline=True, save_figure=True)

# %%
from gradecc.stats.pairwise_ttests import seed_ttests
from gradecc.seed_conn import seed_connectivity

for sample_region in rois:
    df_seed = seed_connectivity(sample_region)
    df_seed_shift = seed_ttests(df_seed, filename=sample_region[10:])

    for pair in df_seed_shift.index.unique():
        text = sample_region[10:] + ' seed ' + pair[0][0].upper() + ' to ' + pair[1][0].upper()
        plot_cortex(df_seed_shift.loc[pair], 'tstat',
                   text=text, color_range=(-4, 4), color_map='bwr', layout='grid',
                   save_figure=True)
# Out:
# Computing ttests...
# 100%|██████████| 998/998 [00:11<00:00, 90.06it/s]
# Computing ttests...
#  34%|███▍      | 340/998 [00:03<00:07, 88.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       4 for sample_region in rois:
#       5     df_seed = seed_connectivity(sample_region)
# ----> 6     df_seed_shift = seed_ttests(df_seed, filename=sample_region[10:])
#       8     for pair in df_seed_shift.index.unique():
#       9         text = sample_region[10:] + ' seed ' + pair[0][0].upper() + ' to ' + pair[1][0].upper()
#
# File ~/Dropbox/JasonANDQasem_SHARED/codes/gradients-rl-task/gradecc/stats/pairwise_ttests.py:48, in seed_ttests(df_seed, **kwargs)
#      46 def seed_ttests(df_seed, **kwargs):
#      47     df_seed = melt_df(df_seed)
# ---> 48     return make_ttests(df_seed, save=True, **kwargs)
#
# File ~/Dropbox/JasonANDQasem_SHARED/codes/gradients-rl-task/gradecc/stats/pairwise_ttests.py:24, in make_ttests(df, save, **kwargs)
#      22 df_grouped, index = _prepare_for_seed_conn(df)
#      23 print('Computing ttests...')
# ---> 24 df_stats_pairwise = df_grouped.progress_apply(pg.pairwise_ttests, dv='value', between='epic',
#      25                                               subject='subject', padjust=FDR_method)
#      26 df_stats_pairwise = df_stats_pairwise.reset_index().set_index(index)[['region', 'T', 'p-corr']]
#      27 df_stats_pairwise = df_stats_pairwise.rename(columns={'p-corr': 'pvalue_corrected', 'T': 'tstat'})
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1414, in GroupBy.apply(self, func, *args, **kwargs)
#    1412 with option_context("mode.chained_assignment", None):
#    1413     try:
# -> 1414         result = self._python_apply_general(f, self._selected_obj)
#    1415     except TypeError:
#    1416         # gh-20949
#    1417         # try again, with .apply acting as a filtering
#    (...)
#    1421         # fails on *some* columns, e.g. a numeric operation
#    1422         # on a string grouper column
#    1424         with self._group_selection_context():
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1455, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1429 @final
#    1430 def _python_apply_general(
#    1431     self,
#    (...)
#    1434     not_indexed_same: bool | None = None,
#    1435 ) -> DataFrame | Series:
#    1436     """
#    1437     Apply function f in python space
#    1438
#    (...)
#    1453         data after applying f
#    1454     """
# -> 1455     values, mutated = self.grouper.apply(f, data, self.axis)
#    1457     if not_indexed_same is None:
#    1458         not_indexed_same = mutated or self.mutated
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/groupby/ops.py:761, in BaseGrouper.apply(self, f, data, axis)
#     759 # group might be modified
#     760 group_axes = group.axes
# --> 761 res = f(group)
#     762 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763     mutated = True
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1388, in GroupBy.apply.<locals>.f(g)
#    1385 @wraps(func)
#    1386 def f(g):
#    1387     with np.errstate(all="ignore"):
# -> 1388         return func(g, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pingouin/pairwise.py:350, in pairwise_ttests(data, dv, between, within, subject, parametric, marginal, alpha, alternative, padjust, effsize, correction, nan_policy, return_desc, interaction, within_first)
#     347     df_ttest = ttest(
#     348         x, y, paired=paired, alternative=alternative, correction=correction)
#     349     stats.at[i, 'BF10'] = df_ttest.at['T-test', 'BF10']
# --> 350     stats.at[i, 'dof'] = df_ttest.at['T-test', 'dof']
#     351 else:
#     352     if paired:
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/indexing.py:2281, in _AtIndexer.__setitem__(self, key, value)
#    2278     self.obj.loc[key] = value
#    2279     return
# -> 2281 return super().__setitem__(key, value)
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/indexing.py:2236, in _ScalarAccessIndexer.__setitem__(self, key, value)
#    2233 if len(key) != self.ndim:
#    2234     raise ValueError("Not enough indexers for scalar access (setting)!")
# -> 2236 self.obj._set_value(*key, value=value, takeable=self._takeable)
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/frame.py:3873, in DataFrame._set_value(self, index, col, value, takeable)
#    3869         loc = self.index.get_loc(index)
#    3871     # setitem_inplace will do validation that may raise TypeError
#    3872     #  or ValueError
# -> 3873     series._mgr.setitem_inplace(loc, value)
#    3875 except (KeyError, TypeError, ValueError):
#    3876     # set using a non-recursive method & reset the cache
#    3877     if takeable:
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/internals/base.py:188, in SingleDataManager.setitem_inplace(self, indexer, value)
#     184 # EAs will do this validation in their own __setitem__ methods.
#     185 if isinstance(arr, np.ndarray):
#     186     # Note: checking for ndarray instead of np.dtype means we exclude
#     187     #  dt64/td64, which do their own validation.
# --> 188     value = np_can_hold_element(arr.dtype, value)
#     190 arr[indexer] = value
#
# File ~/opt/anaconda3/envs/brainv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:2262, in np_can_hold_element(dtype, element)
#    2259 if tipo.kind not in ["f", "i", "u"]:
#    2260     # Anything other than float/integer we cannot hold
#    2261     raise ValueError
# -> 2262 elif not isinstance(tipo, np.dtype):
#    2263     # i.e. nullable IntegerDtype or FloatingDtype;
#    2264     #  we can put this into an ndarray losslessly iff it has no NAs
#    2265     hasnas = element._mask.any()
#    2266     # TODO: don't rely on implementation detail
#
# KeyboardInterrupt:
